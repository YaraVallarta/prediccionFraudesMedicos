# %%
# %pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
#      ------------------------------------ 226.0/226.0 kB 985.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\lemus\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lemus\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\lemus\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lemus\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lemus\appdata\roaming\python\python311\site-packages (from imbalanced-learn) (3.1.0)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.10.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (C:\Users\lemus\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\lemus\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\lemus\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\lemus\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\lemus\AppData\Roaming\Python\Python311\site-packages)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder , OrdinalEncoder , LabelEncoder
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight

# %%
Train=pd.read_csv("data/Train-1542865627584.csv")
Train_Beneficiarydata=pd.read_csv("data/Train_Beneficiarydata-1542865627584.csv")
Train_Inpatientdata=pd.read_csv("data/Train_Inpatientdata-1542865627584.csv")
Train_Outpatientdata=pd.read_csv("data/Train_Outpatientdata-1542865627584.csv")

# %% [markdown]
# # Merging data

# %%
Train_Allpatientdata=pd.merge(Train_Outpatientdata,Train_Inpatientdata,
                              left_on=['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
       'ClmAdmitDiagnosisCode'],
                              right_on=['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
       'ClmAdmitDiagnosisCode']
                              ,how='outer')

# %%
Train_Allpatientdata=pd.merge(Train_Allpatientdata,Train_Beneficiarydata,on="BeneID")

# %%
Train_Allpatientdata=pd.merge(Train_Allpatientdata,Train,on="Provider")

# %%
Train_Allpatientdata.shape
# Out:
# (558211, 55)

# %%
Train_Allpatientdata.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 2  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# 3  BENE11004  CLM173224   2009-02-03  2009-02-03  PRV56011
# 4  BENE11004  CLM224741   2009-03-03  2009-03-03  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      40          PHY334319                NaN
# 2                     200          PHY403831                NaN
# 3                      20          PHY339887                NaN
# 4                      40          PHY345721                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ChronicCond_Diabetes  \
# 0            NaN              78943  ...                    2
# 1            NaN              71988  ...                    1
# 2            NaN              82382  ...                    1
# 3            NaN              20381  ...                    1
# 4            NaN              V6546  ...                    1
#
#   ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 0                         2                        2
# 1                         1                        1
# 2                         1                        1
# 3                         1                        1
# 4                         1                        1
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke IPAnnualReimbursementAmt  \
# 0                               2                  2                        0
# 1                               1                  2                        0
# 2                               1                  2                        0
# 3                               1                  2                        0
# 4                               1                  2                        0
#
#   IPAnnualDeductibleAmt OPAnnualReimbursementAmt OPAnnualDeductibleAmt  \
# 0                     0                       30                    50
# 1                     0                     1810                   760
# 2                     0                     1810                   760
# 3                     0                     1810                   760
# 4                     0                     1810                   760
#
#    PotentialFraud
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes
#
# [5 rows x 55 columns]

# %%
Train_Allpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558211 entries, 0 to 558210
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   ClmDiagnosisCode_1               547758 non-null  object
#  10  ClmDiagnosisCode_2               362605 non-null  object
#  11  ClmDiagnosisCode_3               243055 non-null  object
#  12  ClmDiagnosisCode_4               164536 non-null  object
#  13  ClmDiagnosisCode_5               111924 non-null  object
#  14  ClmDiagnosisCode_6               84392 non-null   object
#  15  ClmDiagnosisCode_7               66177 non-null   object
#  16  ClmDiagnosisCode_8               53444 non-null   object
#  17  ClmDiagnosisCode_9               41815 non-null   object
#  18  ClmDiagnosisCode_10              5010 non-null    object
#  19  ClmProcedureCode_1               23310 non-null   float64
#  20  ClmProcedureCode_2               5490 non-null    float64
#  21  ClmProcedureCode_3               969 non-null     float64
#  22  ClmProcedureCode_4               118 non-null     float64
#  23  ClmProcedureCode_5               9 non-null       float64
#  24  ClmProcedureCode_6               0 non-null       float64
#  25  DeductibleAmtPaid                557312 non-null  float64
#  26  ClmAdmitDiagnosisCode            145899 non-null  object
#  27  AdmissionDt                      40474 non-null   object
#  28  DischargeDt                      40474 non-null   object
#  29  DiagnosisGroupCode               40474 non-null   object
#  30  DOB                              558211 non-null  object
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  PotentialFraud                   558211 non-null  object
# dtypes: float64(7), int64(22), object(26)
# memory usage: 238.5+ MB

# %% [markdown]
# # Physician cols preprocessing

# %%
a=(Train_Allpatientdata["AttendingPhysician"]==Train_Allpatientdata["OperatingPhysician"])
b=(Train_Allpatientdata["OperatingPhysician"]==Train_Allpatientdata["OtherPhysician"])
c=(Train_Allpatientdata["AttendingPhysician"]==Train_Allpatientdata["OtherPhysician"])

print(a.sum())
print(b.sum())
print(c.sum())
print( (a+b).sum() ) # atten=oper=other
# Out:
# 61164
# 15884
# 85258
# 63872

# %%
def physician_same(row):
    atten_oper=row["AttendingPhysician"]==row["OperatingPhysician"]
    oper_other=row["OperatingPhysician"]==row["OtherPhysician"]
    atten_other=row["AttendingPhysician"]==row["OtherPhysician"]
    if atten_oper==True and oper_other==True:# atten = oper = other
        return 0
    elif atten_oper==True and oper_other==False:# atten = oper != other
        return 1
    elif atten_oper==False and oper_other==True:# atten != oper = other
        return 2
    else:# atten != oper != other
        return 3
    
phy_same=Train_Allpatientdata.apply(physician_same,axis=1)

# %%
Train_Allpatientdata["phy_same"]=phy_same

# %%
def physician_count(row,list_count):
    count=0
    for col in list_count:
        if pd.isnull(row[col]):
            continue
        else:
            count+=1
    return count
    
list_count=["AttendingPhysician","OperatingPhysician","OtherPhysician"]
phy_count=Train_Allpatientdata.apply(physician_count,axis=1,args=(list_count,))

# %%
Train_Allpatientdata["phy_count"]=phy_count

# %%
Train_Allpatientdata.head(4)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 2  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# 3  BENE11004  CLM173224   2009-02-03  2009-02-03  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      40          PHY334319                NaN
# 2                     200          PHY403831                NaN
# 3                      20          PHY339887                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ChronicCond_Osteoporasis  \
# 0            NaN              78943  ...                        2
# 1            NaN              71988  ...                        1
# 2            NaN              82382  ...                        1
# 3            NaN              20381  ...                        1
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke IPAnnualReimbursementAmt  \
# 0                               2                  2                        0
# 1                               1                  2                        0
# 2                               1                  2                        0
# 3                               1                  2                        0
#
#   IPAnnualDeductibleAmt OPAnnualReimbursementAmt OPAnnualDeductibleAmt  \
# 0                     0                       30                    50
# 1                     0                     1810                   760
# 2                     0                     1810                   760
# 3                     0                     1810                   760
#
#   PotentialFraud phy_same  phy_count
# 0            Yes        3          1
# 1            Yes        3          1
# 2            Yes        3          1
# 3            Yes        3          1
#
# [4 rows x 57 columns]

# %% [markdown]
# # ClainStartDt , ClainEndDt cols preprocessing

# %%
startdate= pd.to_datetime( Train_Allpatientdata["ClaimStartDt"] )
enddate= pd.to_datetime( Train_Allpatientdata["ClaimEndDt"] )

period = ( enddate - startdate).dt.days
Train_Allpatientdata["period"] = period

# %%
Train_Allpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558211 entries, 0 to 558210
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   ClmDiagnosisCode_1               547758 non-null  object
#  10  ClmDiagnosisCode_2               362605 non-null  object
#  11  ClmDiagnosisCode_3               243055 non-null  object
#  12  ClmDiagnosisCode_4               164536 non-null  object
#  13  ClmDiagnosisCode_5               111924 non-null  object
#  14  ClmDiagnosisCode_6               84392 non-null   object
#  15  ClmDiagnosisCode_7               66177 non-null   object
#  16  ClmDiagnosisCode_8               53444 non-null   object
#  17  ClmDiagnosisCode_9               41815 non-null   object
#  18  ClmDiagnosisCode_10              5010 non-null    object
#  19  ClmProcedureCode_1               23310 non-null   float64
#  20  ClmProcedureCode_2               5490 non-null    float64
#  21  ClmProcedureCode_3               969 non-null     float64
#  22  ClmProcedureCode_4               118 non-null     float64
#  23  ClmProcedureCode_5               9 non-null       float64
#  24  ClmProcedureCode_6               0 non-null       float64
#  25  DeductibleAmtPaid                557312 non-null  float64
#  26  ClmAdmitDiagnosisCode            145899 non-null  object
#  27  AdmissionDt                      40474 non-null   object
#  28  DischargeDt                      40474 non-null   object
#  29  DiagnosisGroupCode               40474 non-null   object
#  30  DOB                              558211 non-null  object
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  PotentialFraud                   558211 non-null  object
#  55  phy_same                         558211 non-null  int64
#  56  phy_count                        558211 non-null  int64
#  57  period                           558211 non-null  int64
# dtypes: float64(7), int64(25), object(26)
# memory usage: 251.3+ MB

# %% [markdown]
# ## taking copy

# %%
copy1=Train_Allpatientdata.copy()

# %% [markdown]
# # Cronic code cols preprocessing

# %%
cronic_cols_names=copy1.columns[ copy1.columns.str.startswith("ChronicCond") ]
cronic_cols=copy1[   cronic_cols_names   ]
cronic=cronic_cols.replace({2:0})
copy1[   cronic_cols_names   ]=cronic

# %% [markdown]
# # Potintial fraud preprocessing

# %%
copy1["PotentialFraud"]=copy1["PotentialFraud"].replace({"Yes":1,"No":0})

# %% [markdown]
# # gender preprocessing

# %%
copy1["Gender"]=copy1["Gender"].replace({2:0})

# %% [markdown]
# # Admisson data preprocessing

# %%
startadmt= pd.to_datetime( copy1["AdmissionDt"] )
enddatadmt= pd.to_datetime( copy1["DischargeDt"] )

periodadmt = ( enddatadmt - startadmt).dt.days
copy1["periodadmt"] = periodadmt
copy1["periodadmt"]=copy1["periodadmt"].fillna(0)

# %% [markdown]
# # RenalDiseaseIndicator preprocessing

# %%
copy1["RenalDiseaseIndicator"]=copy1["RenalDiseaseIndicator"].replace({"Y":1})

# %% [markdown]
# # patient age preprocessing

# %%
birthdate=pd.to_datetime(copy1["DOB"])
enddate=pd.to_datetime(copy1["DOD"])

# cheack whether the patient dead or alife
def alife_function(value):
    if value==True:
        return 1
    else:
        return 0
alife = pd.isna(enddate).apply(alife_function)


# get the age of patient
max_date=enddate.dropna().max()
enddate[pd.isna(enddate)]=max_date
period=(((enddate-birthdate).dt.days/356).astype(int))

copy1["age"]=period
copy1["alife"]=alife

# %%
copy1.head(2)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      40          PHY334319                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... IPAnnualDeductibleAmt  \
# 0            NaN              78943  ...                     0
# 1            NaN              71988  ...                     0
#
#   OPAnnualReimbursementAmt OPAnnualDeductibleAmt PotentialFraud phy_same  \
# 0                       30                    50              1        3
# 1                     1810                   760              1        3
#
#   phy_count period periodadmt age  alife
# 0         1      0        0.0  75      1
# 1         1      0        0.0  89      1
#
# [2 rows x 61 columns]

# %%
copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558211 entries, 0 to 558210
# Data columns (total 61 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   ClmDiagnosisCode_1               547758 non-null  object
#  10  ClmDiagnosisCode_2               362605 non-null  object
#  11  ClmDiagnosisCode_3               243055 non-null  object
#  12  ClmDiagnosisCode_4               164536 non-null  object
#  13  ClmDiagnosisCode_5               111924 non-null  object
#  14  ClmDiagnosisCode_6               84392 non-null   object
#  15  ClmDiagnosisCode_7               66177 non-null   object
#  16  ClmDiagnosisCode_8               53444 non-null   object
#  17  ClmDiagnosisCode_9               41815 non-null   object
#  18  ClmDiagnosisCode_10              5010 non-null    object
#  19  ClmProcedureCode_1               23310 non-null   float64
#  20  ClmProcedureCode_2               5490 non-null    float64
#  21  ClmProcedureCode_3               969 non-null     float64
#  22  ClmProcedureCode_4               118 non-null     float64
#  23  ClmProcedureCode_5               9 non-null       float64
#  24  ClmProcedureCode_6               0 non-null       float64
#  25  DeductibleAmtPaid                557312 non-null  float64
#  26  ClmAdmitDiagnosisCode            145899 non-null  object
#  27  AdmissionDt                      40474 non-null   object
#  28  DischargeDt                      40474 non-null   object
#  29  DiagnosisGroupCode               40474 non-null   object
#  30  DOB                              558211 non-null  object
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  PotentialFraud                   558211 non-null  int64
#  55  phy_same                         558211 non-null  int64
#  56  phy_count                        558211 non-null  int64
#  57  period                           558211 non-null  int64
#  58  periodadmt                       558211 non-null  float64
#  59  age                              558211 non-null  int32
#  60  alife                            558211 non-null  int64
# dtypes: float64(8), int32(1), int64(27), object(25)
# memory usage: 261.9+ MB

# %% [markdown]
# # means and stds

# %%
def groupby(df,by,vars_to_group,methods,col_ident,as_index=True,agg=False):
    if agg:
        grouped=df.groupby(by=by,as_index=as_index)[vars_to_group].agg(methods)
        cols=['_'.join(col) for col in grouped.columns.values]
        cols=[col_ident+"_"+col for col in cols]
        grouped.columns=cols
        return grouped
    
    else:
        concat=df.groupby(by=by,as_index=as_index)[vars_to_group].transform(methods[0])
        cols=[ col_ident+"_"+col+"_"+methods[0] for col in concat.columns ]
        concat.columns=cols
        
        for method in methods[1:]:
            grouped=df.groupby(by=by,as_index=as_index)[vars_to_group].transform(method)
            cols=[col_ident+"_"+col+"_"+method for col in grouped.columns]
            grouped.columns=cols
            concat=pd.concat([concat,grouped],axis=1)
        
        return concat

# %%
money_cols=["InscClaimAmtReimbursed","DeductibleAmtPaid","NoOfMonths_PartACov","NoOfMonths_PartBCov",
           "IPAnnualReimbursementAmt","IPAnnualDeductibleAmt","OPAnnualReimbursementAmt","OPAnnualDeductibleAmt"]

# %%
provider_money=groupby(copy1,["Provider"],money_cols,["mean","std"],"provider",
                       True,False)

# %%
banel_money=groupby(copy1,["BeneID"],money_cols,["mean","std"],"banel",
                       True,False)

# %%
diag1_money=groupby(copy1,["ClmDiagnosisCode_1"],money_cols,["mean","std"],"diag1",
                       True,False)

# %%
selected_cols_names=["phy_same","phy_count","period","periodadmt","age","alife","Provider","PotentialFraud"]
selected_cols=copy1[selected_cols_names]

# %%
data=pd.concat([selected_cols,provider_money,banel_money,diag1_money],axis=1)

# %%
grouped=data.groupby(by=["Provider","PotentialFraud"]).agg("mean").reset_index()

# %%
grouped
# Out:
#       Provider  PotentialFraud  phy_same  phy_count    period  periodadmt  \
# 0     PRV51001               0  2.960000   1.600000  1.440000    1.000000
# 1     PRV51003               1  2.439394   1.530303  3.674242    2.424242
# 2     PRV51004               0  2.818792   1.604027  1.429530    0.000000
# 3     PRV51005               1  2.731330   1.599142  1.088412    0.000000
# 4     PRV51007               0  2.736111   1.527778  0.958333    0.222222
# ...        ...             ...       ...        ...       ...         ...
# 5405  PRV57759               0  2.892857   1.464286  2.142857    0.000000
# 5406  PRV57760               0  2.318182   1.681818  0.318182    0.000000
# 5407  PRV57761               0  3.000000   1.609756  1.390244    0.000000
# 5408  PRV57762               0  3.000000   1.000000  0.000000    0.000000
# 5409  PRV57763               0  2.601695   1.576271  1.720339    0.000000
#
#             age     alife  provider_InscClaimAmtReimbursed_mean  \
# 0     80.240000  1.000000                           4185.600000
# 1     71.371212  0.992424                           4588.409091
# 2     73.516779  0.993289                            350.134228
# 3     71.783691  0.996567                            241.124464
# 4     70.583333  0.986111                            468.194444
# ...         ...       ...                                   ...
# 5405  75.285714  1.000000                            380.000000
# 5406  62.318182  1.000000                            216.818182
# 5407  73.268293  0.987805                            225.243902
# 5408  69.000000  1.000000                           1900.000000
# 5409  75.423729  1.000000                            369.576271
#
#       provider_DeductibleAmtPaid_mean  ...  \
# 0                          213.600000  ...
# 1                          502.166667  ...
# 2                            2.080537  ...
# 3                            3.175966  ...
# 4                           45.333333  ...
# ...                               ...  ...
# 5405                         4.642857  ...
# 5406                         0.000000  ...
# 5407                         4.512195  ...
# 5408                         0.000000  ...
# 5409                         3.305085  ...
#
#       diag1_OPAnnualReimbursementAmt_mean  diag1_OPAnnualDeductibleAmt_mean  \
# 0                             1804.331094                        543.045084
# 1                             2422.458599                        676.313985
# 2                             2430.017927                        694.246881
# 3                             2195.953526                        630.805985
# 4                             2089.969651                        606.550334
# ...                                   ...                               ...
# 5405                          2770.995487                        762.684094
# 5406                          1857.020747                        551.812490
# 5407                          2409.246660                        667.100333
# 5408                          2332.103825                        701.530055
# 5409                          2324.141731                        667.799460
#
#       diag1_InscClaimAmtReimbursed_std  diag1_DeductibleAmtPaid_std  \
# 0                          3482.066310                   161.353027
# 1                          4017.871066                   260.257069
# 2                          1536.290845                   113.086257
# 3                          1234.005090                    91.141252
# 4                          1519.425993                   103.302166
# ...                                ...                          ...
# 5405                        924.661538                    88.673186
# 5406                       1182.800362                    63.746284
# 5407                       1469.587798                    89.369298
# 5408                        926.436661                   146.810805
# 5409                       1036.401611                    82.166327
#
#       diag1_NoOfMonths_PartACov_std  diag1_NoOfMonths_PartBCov_std  \
# 0                          0.569945                       0.424192
# 1                          0.726572                       0.653285
# 2                          0.667719                       0.577420
# 3                          0.657071                       0.565930
# 4                          0.626542                       0.520122
# ...                             ...                            ...
# 5405                       0.717266                       0.575517
# 5406                       0.738778                       0.632455
# 5407                       0.626573                       0.503166
# 5408                       0.939796                       0.000000
# 5409                       0.689070                       0.606932
#
#       diag1_IPAnnualReimbursementAmt_std  diag1_IPAnnualDeductibleAmt_std  \
# 0                           12941.552352                      1205.297144
# 1                           12620.604411                      1226.306633
# 2                           11016.516937                      1111.592405
# 3                           10021.329572                       957.701391
# 4                           10565.761429                      1126.358206
# ...                                  ...                              ...
# 5405                        11706.835391                       989.925167
# 5406                        10087.266945                       852.726747
# 5407                         9701.587916                       956.791480
# 5408                        10836.121659                       798.136760
# 5409                        10163.343892                       961.863114
#
#       diag1_OPAnnualReimbursementAmt_std  diag1_OPAnnualDeductibleAmt_std
# 0                            2450.076771                       661.506672
# 1                            3369.338617                       848.213675
# 2                            2972.377916                       808.138208
# 3                            2727.944083                       737.419878
# 4                            2486.827069                       682.279276
# ...                                  ...                              ...
# 5405                         3092.516228                       805.101036
# 5406                         2325.052621                       667.813928
# 5407                         2864.403847                       730.914731
# 5408                         2327.892739                       625.238022
# 5409                         2735.861878                       769.458419
#
# [5410 rows x 56 columns]

# %%
grouped=grouped.fillna(0)

# %%
features=grouped.iloc[:,2:]
labels=grouped.iloc[:,1]

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
features, labels = oversample.fit_resample(features, labels)

# %%
scaler = StandardScaler()
featuresstand=scaler.fit_transform(features)

# %%
ff=compute_class_weight(class_weight="balanced",classes=np.unique(labels),y=labels)
cw=dict(zip(np.unique(labels),ff))

featuress,labelss=shuffle(featuresstand,labels)
xtrain,xtest,ytrain,ytest = train_test_split(featuress,labelss,test_size=0.1)

# %%
xtrain=xtrain.astype(np.float32)
xtest=xtest.astype(np.float32)
ytrain=ytrain.astype(np.float32).to_numpy()
ytest=ytest.astype(np.float32).to_numpy()


ytrain=ytrain.reshape(ytrain.shape+(1,))
ytest=ytest.reshape(ytest.shape+(1,))

print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (8827, 54)
# (981, 54)
# (8827, 1)
# (981, 1)

# %%
inpt=tf.keras.layers.Input((xtrain.shape[1]))
d1=tf.keras.layers.Dense(256, activation='relu')(inpt)
d1=tf.keras.layers.Dense(128, activation='relu')(d1)

d2=tf.keras.layers.Dense(1,activation="sigmoid")(d1)

nural_network=tf.keras.Model(inputs=inpt,outputs=d2)

# %%
nural_network.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss='binary_crossentropy'
                    ,metrics=["accuracy"])

history_combined=nural_network.fit(xtrain,ytrain,validation_data=(xtest,ytest),batch_size=128,epochs=300,
                                  class_weight=cw)
# Out:
# Epoch 1/300
# 69/69 [==============================] - 2s 6ms/step - loss: 0.5794 - accuracy: 0.6757 - val_loss: 0.5255 - val_accuracy: 0.7166
# Epoch 2/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.4623 - accuracy: 0.7878 - val_loss: 0.4538 - val_accuracy: 0.7910
# Epoch 3/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8397 - val_loss: 0.4111 - val_accuracy: 0.8226
# Epoch 4/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8604 - val_loss: 0.3854 - val_accuracy: 0.8287
# Epoch 5/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8659 - val_loss: 0.3678 - val_accuracy: 0.8389
# Epoch 6/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8716 - val_loss: 0.3540 - val_accuracy: 0.8451
# Epoch 7/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.3088 - accuracy: 0.8769 - val_loss: 0.3441 - val_accuracy: 0.8542
# Epoch 8/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2981 - accuracy: 0.8808 - val_loss: 0.3343 - val_accuracy: 0.8573
# Epoch 9/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2892 - accuracy: 0.8838 - val_loss: 0.3256 - val_accuracy: 0.8654
# Epoch 10/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2811 - accuracy: 0.8877 - val_loss: 0.3194 - val_accuracy: 0.8726
# Epoch 11/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.8917 - val_loss: 0.3131 - val_accuracy: 0.8736
# Epoch 12/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2680 - accuracy: 0.8940 - val_loss: 0.3081 - val_accuracy: 0.8777
# Epoch 13/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2622 - accuracy: 0.8987 - val_loss: 0.3028 - val_accuracy: 0.8828
# Epoch 14/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2576 - accuracy: 0.9004 - val_loss: 0.3002 - val_accuracy: 0.8869
# Epoch 15/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9033 - val_loss: 0.2961 - val_accuracy: 0.8899
# Epoch 16/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.9064 - val_loss: 0.2911 - val_accuracy: 0.8950
# Epoch 17/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.9081 - val_loss: 0.2875 - val_accuracy: 0.8930
# Epoch 18/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.9104 - val_loss: 0.2842 - val_accuracy: 0.8970
# Epoch 19/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.9134 - val_loss: 0.2825 - val_accuracy: 0.8930
# Epoch 20/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9124 - val_loss: 0.2779 - val_accuracy: 0.8950
# Epoch 21/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9145 - val_loss: 0.2744 - val_accuracy: 0.8950
# Epoch 22/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2249 - accuracy: 0.9171 - val_loss: 0.2714 - val_accuracy: 0.8970
# Epoch 23/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.9185 - val_loss: 0.2679 - val_accuracy: 0.8970
# Epoch 24/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2183 - accuracy: 0.9199 - val_loss: 0.2648 - val_accuracy: 0.9001
# Epoch 25/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2147 - accuracy: 0.9214 - val_loss: 0.2623 - val_accuracy: 0.9001
# Epoch 26/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2111 - accuracy: 0.9224 - val_loss: 0.2598 - val_accuracy: 0.9042
# Epoch 27/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.9229 - val_loss: 0.2568 - val_accuracy: 0.9072
# Epoch 28/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2049 - accuracy: 0.9241 - val_loss: 0.2531 - val_accuracy: 0.9062
# Epoch 29/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2017 - accuracy: 0.9266 - val_loss: 0.2506 - val_accuracy: 0.9042
# Epoch 30/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1992 - accuracy: 0.9273 - val_loss: 0.2481 - val_accuracy: 0.9052
# Epoch 31/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.9277 - val_loss: 0.2485 - val_accuracy: 0.9042
# Epoch 32/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.9295 - val_loss: 0.2434 - val_accuracy: 0.9042
# Epoch 33/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.9309 - val_loss: 0.2414 - val_accuracy: 0.9093
# Epoch 34/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1874 - accuracy: 0.9313 - val_loss: 0.2388 - val_accuracy: 0.9083
# Epoch 35/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1854 - accuracy: 0.9335 - val_loss: 0.2355 - val_accuracy: 0.9062
# Epoch 36/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 0.9324 - val_loss: 0.2350 - val_accuracy: 0.9072
# Epoch 37/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9353 - val_loss: 0.2321 - val_accuracy: 0.9123
# Epoch 38/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1769 - accuracy: 0.9367 - val_loss: 0.2310 - val_accuracy: 0.9103
# Epoch 39/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9380 - val_loss: 0.2286 - val_accuracy: 0.9144
# Epoch 40/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1720 - accuracy: 0.9385 - val_loss: 0.2249 - val_accuracy: 0.9123
# Epoch 41/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1704 - accuracy: 0.9397 - val_loss: 0.2241 - val_accuracy: 0.9154
# Epoch 42/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.9413 - val_loss: 0.2240 - val_accuracy: 0.9123
# Epoch 43/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.9417 - val_loss: 0.2193 - val_accuracy: 0.9154
# Epoch 44/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1628 - accuracy: 0.9431 - val_loss: 0.2174 - val_accuracy: 0.9205
# Epoch 45/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9430 - val_loss: 0.2149 - val_accuracy: 0.9195
# Epoch 46/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1584 - accuracy: 0.9448 - val_loss: 0.2143 - val_accuracy: 0.9246
# Epoch 47/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1566 - accuracy: 0.9438 - val_loss: 0.2123 - val_accuracy: 0.9215
# Epoch 48/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1548 - accuracy: 0.9453 - val_loss: 0.2111 - val_accuracy: 0.9246
# Epoch 49/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1526 - accuracy: 0.9460 - val_loss: 0.2083 - val_accuracy: 0.9246
# Epoch 50/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1506 - accuracy: 0.9492 - val_loss: 0.2059 - val_accuracy: 0.9286
# Epoch 51/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1479 - accuracy: 0.9487 - val_loss: 0.2048 - val_accuracy: 0.9307
# Epoch 52/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1461 - accuracy: 0.9502 - val_loss: 0.2041 - val_accuracy: 0.9337
# Epoch 53/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9496 - val_loss: 0.2034 - val_accuracy: 0.9276
# Epoch 54/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1419 - accuracy: 0.9525 - val_loss: 0.2000 - val_accuracy: 0.9358
# Epoch 55/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9525 - val_loss: 0.2005 - val_accuracy: 0.9317
# Epoch 56/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 0.9522 - val_loss: 0.1965 - val_accuracy: 0.9337
# Epoch 57/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1370 - accuracy: 0.9541 - val_loss: 0.1958 - val_accuracy: 0.9348
# Epoch 58/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1355 - accuracy: 0.9541 - val_loss: 0.1939 - val_accuracy: 0.9358
# Epoch 59/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9553 - val_loss: 0.1933 - val_accuracy: 0.9348
# Epoch 60/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1318 - accuracy: 0.9556 - val_loss: 0.1950 - val_accuracy: 0.9348
# Epoch 61/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1306 - accuracy: 0.9567 - val_loss: 0.1917 - val_accuracy: 0.9358
# Epoch 62/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.9560 - val_loss: 0.1901 - val_accuracy: 0.9388
# Epoch 63/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9585 - val_loss: 0.1908 - val_accuracy: 0.9388
# Epoch 64/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9585 - val_loss: 0.1873 - val_accuracy: 0.9388
# Epoch 65/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9589 - val_loss: 0.1871 - val_accuracy: 0.9388
# Epoch 66/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9601 - val_loss: 0.1834 - val_accuracy: 0.9409
# Epoch 67/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 0.9608 - val_loss: 0.1837 - val_accuracy: 0.9378
# Epoch 68/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9602 - val_loss: 0.1833 - val_accuracy: 0.9388
# Epoch 69/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1188 - accuracy: 0.9611 - val_loss: 0.1837 - val_accuracy: 0.9429
# Epoch 70/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9616 - val_loss: 0.1824 - val_accuracy: 0.9409
# Epoch 71/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9620 - val_loss: 0.1806 - val_accuracy: 0.9409
# Epoch 72/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9628 - val_loss: 0.1796 - val_accuracy: 0.9368
# Epoch 73/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9642 - val_loss: 0.1780 - val_accuracy: 0.9429
# Epoch 74/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9639 - val_loss: 0.1828 - val_accuracy: 0.9399
# Epoch 75/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9653 - val_loss: 0.1772 - val_accuracy: 0.9460
# Epoch 76/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9650 - val_loss: 0.1792 - val_accuracy: 0.9439
# Epoch 77/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9652 - val_loss: 0.1795 - val_accuracy: 0.9419
# Epoch 78/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1074 - accuracy: 0.9660 - val_loss: 0.1773 - val_accuracy: 0.9388
# Epoch 79/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9670 - val_loss: 0.1733 - val_accuracy: 0.9439
# Epoch 80/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9676 - val_loss: 0.1739 - val_accuracy: 0.9450
# Epoch 81/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.9674 - val_loss: 0.1742 - val_accuracy: 0.9439
# Epoch 82/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9677 - val_loss: 0.1716 - val_accuracy: 0.9419
# Epoch 83/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.9678 - val_loss: 0.1684 - val_accuracy: 0.9429
# Epoch 84/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9686 - val_loss: 0.1710 - val_accuracy: 0.9429
# Epoch 85/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.9690 - val_loss: 0.1686 - val_accuracy: 0.9419
# Epoch 86/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0969 - accuracy: 0.9691 - val_loss: 0.1688 - val_accuracy: 0.9450
# Epoch 87/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9700 - val_loss: 0.1673 - val_accuracy: 0.9470
# Epoch 88/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9702 - val_loss: 0.1677 - val_accuracy: 0.9470
# Epoch 89/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9720 - val_loss: 0.1674 - val_accuracy: 0.9480
# Epoch 90/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9713 - val_loss: 0.1638 - val_accuracy: 0.9480
# Epoch 91/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9720 - val_loss: 0.1636 - val_accuracy: 0.9490
# Epoch 92/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9717 - val_loss: 0.1639 - val_accuracy: 0.9450
# Epoch 93/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9727 - val_loss: 0.1616 - val_accuracy: 0.9480
# Epoch 94/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0884 - accuracy: 0.9726 - val_loss: 0.1612 - val_accuracy: 0.9480
# Epoch 95/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9726 - val_loss: 0.1604 - val_accuracy: 0.9490
# Epoch 96/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9739 - val_loss: 0.1622 - val_accuracy: 0.9470
# Epoch 97/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9741 - val_loss: 0.1592 - val_accuracy: 0.9501
# Epoch 98/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0841 - accuracy: 0.9750 - val_loss: 0.1582 - val_accuracy: 0.9490
# Epoch 99/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9744 - val_loss: 0.1587 - val_accuracy: 0.9501
# Epoch 100/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9744 - val_loss: 0.1576 - val_accuracy: 0.9470
# Epoch 101/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9754 - val_loss: 0.1582 - val_accuracy: 0.9480
# Epoch 102/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9759 - val_loss: 0.1613 - val_accuracy: 0.9490
# Epoch 103/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9761 - val_loss: 0.1570 - val_accuracy: 0.9501
# Epoch 104/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9769 - val_loss: 0.1571 - val_accuracy: 0.9470
# Epoch 105/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9772 - val_loss: 0.1571 - val_accuracy: 0.9501
# Epoch 106/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.9776 - val_loss: 0.1538 - val_accuracy: 0.9501
# Epoch 107/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0755 - accuracy: 0.9770 - val_loss: 0.1559 - val_accuracy: 0.9511
# Epoch 108/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9775 - val_loss: 0.1559 - val_accuracy: 0.9490
# Epoch 109/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9777 - val_loss: 0.1527 - val_accuracy: 0.9490
# Epoch 110/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9785 - val_loss: 0.1525 - val_accuracy: 0.9531
# Epoch 111/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9786 - val_loss: 0.1506 - val_accuracy: 0.9551
# Epoch 112/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9793 - val_loss: 0.1507 - val_accuracy: 0.9511
# Epoch 113/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.9799 - val_loss: 0.1542 - val_accuracy: 0.9490
# Epoch 114/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9798 - val_loss: 0.1515 - val_accuracy: 0.9511
# Epoch 115/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9805 - val_loss: 0.1503 - val_accuracy: 0.9521
# Epoch 116/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0680 - accuracy: 0.9792 - val_loss: 0.1491 - val_accuracy: 0.9541
# Epoch 117/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0689 - accuracy: 0.9790 - val_loss: 0.1486 - val_accuracy: 0.9562
# Epoch 118/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9824 - val_loss: 0.1545 - val_accuracy: 0.9501
# Epoch 119/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9813 - val_loss: 0.1466 - val_accuracy: 0.9551
# Epoch 120/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 0.9819 - val_loss: 0.1511 - val_accuracy: 0.9541
# Epoch 121/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.9826 - val_loss: 0.1465 - val_accuracy: 0.9562
# Epoch 122/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9819 - val_loss: 0.1447 - val_accuracy: 0.9551
# Epoch 123/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9827 - val_loss: 0.1483 - val_accuracy: 0.9531
# Epoch 124/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0625 - accuracy: 0.9826 - val_loss: 0.1484 - val_accuracy: 0.9541
# Epoch 125/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9829 - val_loss: 0.1489 - val_accuracy: 0.9541
# Epoch 126/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 0.9830 - val_loss: 0.1479 - val_accuracy: 0.9541
# Epoch 127/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9836 - val_loss: 0.1495 - val_accuracy: 0.9531
# Epoch 128/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9837 - val_loss: 0.1477 - val_accuracy: 0.9541
# Epoch 129/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9840 - val_loss: 0.1447 - val_accuracy: 0.9572
# Epoch 130/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9846 - val_loss: 0.1449 - val_accuracy: 0.9551
# Epoch 131/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0572 - accuracy: 0.9850 - val_loss: 0.1487 - val_accuracy: 0.9541
# Epoch 132/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9837 - val_loss: 0.1478 - val_accuracy: 0.9531
# Epoch 133/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9849 - val_loss: 0.1422 - val_accuracy: 0.9551
# Epoch 134/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9856 - val_loss: 0.1414 - val_accuracy: 0.9551
# Epoch 135/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9863 - val_loss: 0.1443 - val_accuracy: 0.9562
# Epoch 136/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9863 - val_loss: 0.1450 - val_accuracy: 0.9562
# Epoch 137/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9855 - val_loss: 0.1455 - val_accuracy: 0.9572
# Epoch 138/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9856 - val_loss: 0.1438 - val_accuracy: 0.9562
# Epoch 139/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9865 - val_loss: 0.1413 - val_accuracy: 0.9551
# Epoch 140/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9866 - val_loss: 0.1480 - val_accuracy: 0.9551
# Epoch 141/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9855 - val_loss: 0.1433 - val_accuracy: 0.9572
# Epoch 142/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 0.9862 - val_loss: 0.1468 - val_accuracy: 0.9521
# Epoch 143/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9874 - val_loss: 0.1449 - val_accuracy: 0.9572
# Epoch 144/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9873 - val_loss: 0.1447 - val_accuracy: 0.9572
# Epoch 145/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9877 - val_loss: 0.1437 - val_accuracy: 0.9551
# Epoch 146/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9878 - val_loss: 0.1401 - val_accuracy: 0.9572
# Epoch 147/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9870 - val_loss: 0.1409 - val_accuracy: 0.9572
# Epoch 148/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 0.9883 - val_loss: 0.1382 - val_accuracy: 0.9582
# Epoch 149/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9882 - val_loss: 0.1391 - val_accuracy: 0.9572
# Epoch 150/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9888 - val_loss: 0.1500 - val_accuracy: 0.9521
# Epoch 151/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9888 - val_loss: 0.1412 - val_accuracy: 0.9562
# Epoch 152/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9889 - val_loss: 0.1413 - val_accuracy: 0.9592
# Epoch 153/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9888 - val_loss: 0.1383 - val_accuracy: 0.9562
# Epoch 154/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9891 - val_loss: 0.1457 - val_accuracy: 0.9562
# Epoch 155/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9890 - val_loss: 0.1397 - val_accuracy: 0.9551
# Epoch 156/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0425 - accuracy: 0.9890 - val_loss: 0.1422 - val_accuracy: 0.9572
# Epoch 157/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9894 - val_loss: 0.1472 - val_accuracy: 0.9572
# Epoch 158/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 0.9895 - val_loss: 0.1374 - val_accuracy: 0.9592
# Epoch 159/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9891 - val_loss: 0.1387 - val_accuracy: 0.9572
# Epoch 160/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9901 - val_loss: 0.1393 - val_accuracy: 0.9572
# Epoch 161/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9897 - val_loss: 0.1409 - val_accuracy: 0.9602
# Epoch 162/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 0.9900 - val_loss: 0.1408 - val_accuracy: 0.9582
# Epoch 163/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9900 - val_loss: 0.1412 - val_accuracy: 0.9572
# Epoch 164/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9908 - val_loss: 0.1397 - val_accuracy: 0.9562
# Epoch 165/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 0.9909 - val_loss: 0.1399 - val_accuracy: 0.9582
# Epoch 166/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9907 - val_loss: 0.1367 - val_accuracy: 0.9592
# Epoch 167/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9905 - val_loss: 0.1376 - val_accuracy: 0.9572
# Epoch 168/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9906 - val_loss: 0.1377 - val_accuracy: 0.9602
# Epoch 169/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9909 - val_loss: 0.1389 - val_accuracy: 0.9592
# Epoch 170/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9913 - val_loss: 0.1407 - val_accuracy: 0.9592
# Epoch 171/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9906 - val_loss: 0.1397 - val_accuracy: 0.9592
# Epoch 172/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9923 - val_loss: 0.1416 - val_accuracy: 0.9592
# Epoch 173/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9918 - val_loss: 0.1434 - val_accuracy: 0.9592
# Epoch 174/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9915 - val_loss: 0.1411 - val_accuracy: 0.9582
# Epoch 175/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9922 - val_loss: 0.1412 - val_accuracy: 0.9602
# Epoch 176/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9918 - val_loss: 0.1442 - val_accuracy: 0.9602
# Epoch 177/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9918 - val_loss: 0.1378 - val_accuracy: 0.9582
# Epoch 178/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9921 - val_loss: 0.1396 - val_accuracy: 0.9582
# Epoch 179/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9923 - val_loss: 0.1383 - val_accuracy: 0.9623
# Epoch 180/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9926 - val_loss: 0.1363 - val_accuracy: 0.9602
# Epoch 181/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9930 - val_loss: 0.1421 - val_accuracy: 0.9613
# Epoch 182/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9931 - val_loss: 0.1375 - val_accuracy: 0.9613
# Epoch 183/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9932 - val_loss: 0.1388 - val_accuracy: 0.9623
# Epoch 184/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 0.9927 - val_loss: 0.1343 - val_accuracy: 0.9633
# Epoch 185/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9925 - val_loss: 0.1385 - val_accuracy: 0.9623
# Epoch 186/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9940 - val_loss: 0.1400 - val_accuracy: 0.9613
# Epoch 187/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9934 - val_loss: 0.1404 - val_accuracy: 0.9623
# Epoch 188/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9933 - val_loss: 0.1423 - val_accuracy: 0.9623
# Epoch 189/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9939 - val_loss: 0.1404 - val_accuracy: 0.9623
# Epoch 190/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9935 - val_loss: 0.1435 - val_accuracy: 0.9602
# Epoch 191/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9933 - val_loss: 0.1393 - val_accuracy: 0.9623
# Epoch 192/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 0.1396 - val_accuracy: 0.9633
# Epoch 193/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9942 - val_loss: 0.1441 - val_accuracy: 0.9633
# Epoch 194/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9943 - val_loss: 0.1421 - val_accuracy: 0.9623
# Epoch 195/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9939 - val_loss: 0.1414 - val_accuracy: 0.9613
# Epoch 196/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9944 - val_loss: 0.1423 - val_accuracy: 0.9633
# Epoch 197/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.9949 - val_loss: 0.1409 - val_accuracy: 0.9653
# Epoch 198/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9949 - val_loss: 0.1411 - val_accuracy: 0.9623
# Epoch 199/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9946 - val_loss: 0.1442 - val_accuracy: 0.9643
# Epoch 200/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9946 - val_loss: 0.1475 - val_accuracy: 0.9613
# Epoch 201/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9950 - val_loss: 0.1390 - val_accuracy: 0.9664
# Epoch 202/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9948 - val_loss: 0.1386 - val_accuracy: 0.9653
# Epoch 203/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9943 - val_loss: 0.1473 - val_accuracy: 0.9623
# Epoch 204/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9947 - val_loss: 0.1427 - val_accuracy: 0.9633
# Epoch 205/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9950 - val_loss: 0.1435 - val_accuracy: 0.9653
# Epoch 206/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9954 - val_loss: 0.1464 - val_accuracy: 0.9653
# Epoch 207/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9952 - val_loss: 0.1621 - val_accuracy: 0.9623
# Epoch 208/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9950 - val_loss: 0.1429 - val_accuracy: 0.9643
# Epoch 209/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9948 - val_loss: 0.1470 - val_accuracy: 0.9684
# Epoch 210/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9954 - val_loss: 0.1458 - val_accuracy: 0.9643
# Epoch 211/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9957 - val_loss: 0.1417 - val_accuracy: 0.9623
# Epoch 212/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9956 - val_loss: 0.1443 - val_accuracy: 0.9643
# Epoch 213/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9955 - val_loss: 0.1471 - val_accuracy: 0.9643
# Epoch 214/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9957 - val_loss: 0.1411 - val_accuracy: 0.9653
# Epoch 215/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 0.1398 - val_accuracy: 0.9664
# Epoch 216/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9961 - val_loss: 0.1461 - val_accuracy: 0.9633
# Epoch 217/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9967 - val_loss: 0.1479 - val_accuracy: 0.9684
# Epoch 218/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9964 - val_loss: 0.1487 - val_accuracy: 0.9653
# Epoch 219/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9956 - val_loss: 0.1442 - val_accuracy: 0.9664
# Epoch 220/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9960 - val_loss: 0.1509 - val_accuracy: 0.9643
# Epoch 221/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9966 - val_loss: 0.1512 - val_accuracy: 0.9684
# Epoch 222/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9959 - val_loss: 0.1463 - val_accuracy: 0.9664
# Epoch 223/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9964 - val_loss: 0.1489 - val_accuracy: 0.9664
# Epoch 224/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9966 - val_loss: 0.1431 - val_accuracy: 0.9664
# Epoch 225/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9966 - val_loss: 0.1529 - val_accuracy: 0.9664
# Epoch 226/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9968 - val_loss: 0.1444 - val_accuracy: 0.9674
# Epoch 227/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9968 - val_loss: 0.1567 - val_accuracy: 0.9623
# Epoch 228/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9968 - val_loss: 0.1502 - val_accuracy: 0.9674
# Epoch 229/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9967 - val_loss: 0.1563 - val_accuracy: 0.9653
# Epoch 230/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9967 - val_loss: 0.1448 - val_accuracy: 0.9664
# Epoch 231/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9972 - val_loss: 0.1513 - val_accuracy: 0.9684
# Epoch 232/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9974 - val_loss: 0.1511 - val_accuracy: 0.9684
# Epoch 233/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9974 - val_loss: 0.1529 - val_accuracy: 0.9664
# Epoch 234/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9975 - val_loss: 0.1548 - val_accuracy: 0.9674
# Epoch 235/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9975 - val_loss: 0.1459 - val_accuracy: 0.9664
# Epoch 236/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9975 - val_loss: 0.1569 - val_accuracy: 0.9674
# Epoch 237/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9975 - val_loss: 0.1587 - val_accuracy: 0.9664
# Epoch 238/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9972 - val_loss: 0.1489 - val_accuracy: 0.9674
# Epoch 239/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9976 - val_loss: 0.1600 - val_accuracy: 0.9674
# Epoch 240/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9975 - val_loss: 0.1511 - val_accuracy: 0.9674
# Epoch 241/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9983 - val_loss: 0.1507 - val_accuracy: 0.9674
# Epoch 242/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9977 - val_loss: 0.1537 - val_accuracy: 0.9674
# Epoch 243/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9982 - val_loss: 0.1518 - val_accuracy: 0.9694
# Epoch 244/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9972 - val_loss: 0.1569 - val_accuracy: 0.9674
# Epoch 245/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9980 - val_loss: 0.1558 - val_accuracy: 0.9674
# Epoch 246/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9982 - val_loss: 0.1666 - val_accuracy: 0.9653
# Epoch 247/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9978 - val_loss: 0.1638 - val_accuracy: 0.9664
# Epoch 248/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.1645 - val_accuracy: 0.9664
# Epoch 249/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 0.9982 - val_loss: 0.1580 - val_accuracy: 0.9643
# Epoch 250/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9984 - val_loss: 0.1675 - val_accuracy: 0.9674
# Epoch 251/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9983 - val_loss: 0.1587 - val_accuracy: 0.9664
# Epoch 252/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9985 - val_loss: 0.1632 - val_accuracy: 0.9643
# Epoch 253/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9982 - val_loss: 0.1506 - val_accuracy: 0.9653
# Epoch 254/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.1681 - val_accuracy: 0.9674
# Epoch 255/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9983 - val_loss: 0.1539 - val_accuracy: 0.9684
# Epoch 256/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 0.9988 - val_loss: 0.1583 - val_accuracy: 0.9643
# Epoch 257/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 0.1585 - val_accuracy: 0.9643
# Epoch 258/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.1645 - val_accuracy: 0.9664
# Epoch 259/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9988 - val_loss: 0.1600 - val_accuracy: 0.9643
# Epoch 260/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9988 - val_loss: 0.1648 - val_accuracy: 0.9643
# Epoch 261/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.9986 - val_loss: 0.1648 - val_accuracy: 0.9643
# Epoch 262/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9982 - val_loss: 0.1595 - val_accuracy: 0.9674
# Epoch 263/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 0.9985 - val_loss: 0.1584 - val_accuracy: 0.9653
# Epoch 264/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9989 - val_loss: 0.1600 - val_accuracy: 0.9653
# Epoch 265/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9986 - val_loss: 0.1615 - val_accuracy: 0.9694
# Epoch 266/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.9990 - val_loss: 0.1680 - val_accuracy: 0.9653
# Epoch 267/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 0.9988 - val_loss: 0.1671 - val_accuracy: 0.9674
# Epoch 268/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9985 - val_loss: 0.1639 - val_accuracy: 0.9694
# Epoch 269/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.9993 - val_loss: 0.1681 - val_accuracy: 0.9684
# Epoch 270/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9989 - val_loss: 0.1748 - val_accuracy: 0.9684
# Epoch 271/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9988 - val_loss: 0.1685 - val_accuracy: 0.9643
# Epoch 272/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9991 - val_loss: 0.1754 - val_accuracy: 0.9674
# Epoch 273/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9992 - val_loss: 0.1726 - val_accuracy: 0.9653
# Epoch 274/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.1712 - val_accuracy: 0.9674
# Epoch 275/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9991 - val_loss: 0.1786 - val_accuracy: 0.9664
# Epoch 276/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 0.9990 - val_loss: 0.1632 - val_accuracy: 0.9674
# Epoch 277/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9989 - val_loss: 0.1733 - val_accuracy: 0.9684
# Epoch 278/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9993 - val_loss: 0.1702 - val_accuracy: 0.9674
# Epoch 279/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9991 - val_loss: 0.1661 - val_accuracy: 0.9664
# Epoch 280/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9989 - val_loss: 0.1710 - val_accuracy: 0.9674
# Epoch 281/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9992 - val_loss: 0.1755 - val_accuracy: 0.9664
# Epoch 282/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9993 - val_loss: 0.1683 - val_accuracy: 0.9664
# Epoch 283/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9991 - val_loss: 0.1781 - val_accuracy: 0.9674
# Epoch 284/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.9992 - val_loss: 0.1697 - val_accuracy: 0.9664
# Epoch 285/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9991 - val_loss: 0.1657 - val_accuracy: 0.9674
# Epoch 286/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 0.1678 - val_accuracy: 0.9684
# Epoch 287/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.1719 - val_accuracy: 0.9674
# Epoch 288/300
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9991 - val_loss: 0.1788 - val_accuracy: 0.9664
# Epoch 289/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.1778 - val_accuracy: 0.9653
# Epoch 290/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9994 - val_loss: 0.1735 - val_accuracy: 0.9694
# Epoch 291/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9992 - val_loss: 0.1803 - val_accuracy: 0.9664
# Epoch 292/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9992 - val_loss: 0.1772 - val_accuracy: 0.9684
# Epoch 293/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.1831 - val_accuracy: 0.9664
# Epoch 294/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9993 - val_loss: 0.1970 - val_accuracy: 0.9653
# Epoch 295/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 0.1793 - val_accuracy: 0.9674
# Epoch 296/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9993 - val_loss: 0.1727 - val_accuracy: 0.9674
# Epoch 297/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9993 - val_loss: 0.1770 - val_accuracy: 0.9664
# Epoch 298/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9995 - val_loss: 0.1711 - val_accuracy: 0.9674
# Epoch 299/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9995 - val_loss: 0.1940 - val_accuracy: 0.9664
# Epoch 300/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9993 - val_loss: 0.1904 - val_accuracy: 0.9664

# %%
ytt=nural_network.predict(xtest)
dd=np.round(ytt)
print(classification_report(ytest,dd))
# Out:
# 31/31 [==============================] - 0s 901us/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.94      0.96       484
#          1.0       0.94      1.00      0.97       497
#
#     accuracy                           0.97       981
#    macro avg       0.97      0.97      0.97       981
# weighted avg       0.97      0.97      0.97       981
